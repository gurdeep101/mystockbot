# %%
import os
import openai

import nest_asyncio
nest_asyncio.apply()

from llama_hub.file.unstructured.base import UnstructuredReader
from pathlib import Path

from llama_index.llms import OpenAI

# %%
loader = UnstructuredReader(url="https://api.unstrctured.io", api=True, api_key="ZF5OoW3jYVLvXQhbEyKOiu114TK4Yj")
pr_docs = loader.load_data(file='../data/axis-press-release-q3fy24.pdf', split_documents=True)
# Out:
# [nltk_data] Downloading package punkt to /Users/gurdeep/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/gurdeep/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/miniconda3/envs/llama/lib/python3.10/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~/miniconda3/envs/llama/lib/python3.10/site-packages/urllib3/util/connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
# ...
